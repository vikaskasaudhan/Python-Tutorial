# %% [markdown]
# # 1.Python Output

# %%
print("Vikas Kasaudhan")
# Out:
# Vikas Kasaudhan

# %%
print("Vikas",3,2.7,True,False)
# Out:
# Vikas 3 2.7 True False

# %% [markdown]
# # 2.Data Types

# %% [markdown]
# Integer & Float

# %%
print(1e308)
print(1e309)
print(1.7e308)
print(1.7e309)
# Out:
# 1e+308
# inf
# 1.7e+308
# inf

# %% [markdown]
# Boolean & String

# %%
print(True,False)
print("vikas")
# Out:
# True False
# vikas

# %% [markdown]
# Complex

# %%
print(2+9j)
# Out:
# (2+9j)

# %% [markdown]
# List -> C- array

# %%
print([1,2,3,4])
# Out:
# [1, 2, 3, 4]

# %% [markdown]
# Tuple

# %%
print((1,2,3,4))
# Out:
# (1, 2, 3, 4)

# %% [markdown]
# Sets

# %%
print({1,2,3,4})
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# Dictionary

# %%
print({'Name':"vikas",'age':21,'marks':99})
# Out:
# {'Name': 'vikas', 'age': 21, 'marks': 99}

# %% [markdown]
# Type

# %%
type(2.3)
# Out:
# float

# %% [markdown]
# # 3.Variables
# * Variables are the container that stores data
# * We can make any time anywhere when we need
# * Support Dynamic binding
# * Support dynamic typing
# * Types of variables
# 1. Static Vs Dynamic Typing
# 2. Static Vs Dynamic Binding
# 3. Stylish declaration techniques

# %%
# Dynamic typing
a = 5
# static typing
int a = 5

# %%
# Dynamic Binding
a = 5
print(a)
a = 'vikas'
print(a)

# static Binding
int a = 5 #never change the data type in programe
# Out:
# 5
# vikas

# %%
a=1
b=3
c=5
print(a,b,c)
# Out:
# 1 3 5

# %%
a,b,c=2,3,4
print(a,b,c)
# Out:
# 2 3 4

# %%
a=b=c=4
print(a,b,c)
# Out:
# 4 4 4

# %% [markdown]
# # Comments

# %%
# addition of two numbers
print(2+3)
# Out:
# 5

# %% [markdown]
# # Compiler & Interpreter
# It is the process where codeis converted into binary known as compilation and that application that convert are known as compiler or interpreter

# %% [markdown]
# # Keywords and Identifier
# * Keywords are reserved words which is already defined in compiler or interpreter
# * When we create a name object that is identifier

# %% [markdown]
# # User Input

# %%
input('enter emai')
# Out:
# enter emai vikas@gmail.com
# 'vikas@gmail.com'

# %% [markdown]
# # Type Conversion
# * Implicit->
#   * Interpreter convert self
#   * can not do always
# * Explicit
#   * programmer do self
#   * can not do always
# * Does not change the type of original value create a new value

# %%
print(2+3.4)
# Out:
# 5.4

# %%
# Explicit
    # str --> int
print(int('3'))
# Out:
# 3

# %%
a = input("enter 1st number")
b = input("enter 2nd number")

result = int(a)+int(b)
print(result)
print(type(a))
print(type(b))
print(type(result))
# Out:
# enter 1st number 234
# enter 2nd number 321
# 555
# <class 'str'>
# <class 'str'>
# <class 'int'>

# %%
a = int(input("enter 1st number"))
b = int(input("enter 2nd number"))

result = a+b
print(result)
print(type(a))
print(type(b))
print(type(result))
# Out:
# enter 1st number 345
# enter 2nd number 567
# 912
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %% [markdown]
# # Literals
# Raw value of a variable is literal

# %%
# binary literal
a = 0b1010
print(a)
# decimal literal
b = 218
print(b)
# Octal literal
c = 0o234
print(c)
# hexadecimal literal
d = 0x2345c
print(d)
# Out:
# 10
# 218
# 156
# 144476

# %%
# float literal
float_1 = 23.9
float_2 = 1.5e3
float_3 = 1.5e-3
print(float_1,float_2,float_3)
# Out:
# 23.9 1500.0 0.0015

# %%
# complex literal
a = 3+ 9j
print(a)
print(a.real,a.imag)
# Out:
# (3+9j)
# 3.0 9.0

# %%
# string literal
string = 'vikas'
strings = 'vikas kasaudhan'
char = 'M'
multiline_str ="""This is multiline string with more than one line"""
unicode = u"\U0001f600\U0001F606\U0001F923"
raw_str = r"raw \n string"
raw_str1 = "raw \n string"

print(string)
print(strings)
print(char)
print(multiline_str)
print(unicode)
print(raw_str)
print(raw_str1)
# Out:
# vikas
# vikas kasaudhan
# M
# This is multiline string with more than one line
# 😀😆🤣
# raw \n string
# raw
#  string

# %%
print(True+2,False+2)
# Out:
# 3 2

# %% [markdown]
# We can not take a variable in python so we use None

# %%
k
#this will throw an error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[127], line 1
# ----> 1 k
#
# NameError: name 'k' is not defined

# %%
k=None
print(k)
# Out:
# None

# %%
heads =int(input("enter number of heads"))
legs = int(input("enter number of legs"))
num_dog = legs//4
if legs%2==0:
    if num_dog <= heads and num_dog*4 != legs:
        num_dog -= 1
        legs = legs - num_dog*4
        num_chicken = legs//2
        if(num_dog+num_chicken==heads):
            print("number of dogs = ",num_dog,"number of chicken = ",num_chicken)
        else:
            print("not possible")
    else:
        print("number of dogs = ",num_dog)
else:
    print("Not possible")
# Out:
# enter number of heads 9
# enter number of legs 34
# not possible

# %%
heads =int(input("enter number of heads"))
legs = int(input("enter number of legs"))
if legs%2==0:
    num_dog = legs//4
    num_chick = 0
    if num_dog == heads:
        if(num_chick+num_dog==heads):
            print("number of chicken = ",num_chick,",","number of dogs = ",num_dog)
        else:
            print("Not possible")
    else:
        num_dog = num_dog-1
        legs = legs-num_dog*4
        num_chick = legs//2
        if(num_chick+num_dog==heads):
            print("number of chicken = ",num_chick,",","number of dogs = ",num_dog) 
        else:
            print("Not possible")
else:
    print("Not possible")
# Out:
# enter number of heads 100
# enter number of legs 396
# number of chicken =  2 number of dogs =  98

# %% [markdown]
# # Operators in Python
# No ternary operator in python
#
# * Arithmetic operators
# * Relational
# * Logical
# * Bitwise
# * Assignment
# * Membership

# %%
# arithmetic
print(2+4)
print(3-5)
print(3*5)
print(6/2)
print(7//3)
print(2**3)
# Out:
# 6
# -2
# 15
# 3.0
# 2
# 8

# %%
# Relational
print(3>9)
print(4<9)
print(2>=9)
print(8<=9)
print(2==9)
print(9!=8)
# Out:
# False
# True
# False
# True
# False
# True

# %%
#logical
print(1 and 0)
print(1 or 0)
print(not 1)
# Out:
# 0
# 1
# False

# %%
# Bitwise
print(2 & 3)  #bitwise and
# 010
# 011
#----
# 010
print(2 | 3) # bitwise or
# 010
# 011
#----
# 011
print(2 ^ 3) #bitwise xor
# 010
# 011
#----
# 001
print(~3) #bitwise not
# 011
#----
# 100
print(9 >> 2)  #bitwise rightshift
# 1001 >> 2  →  0010
print(11<< 2)  #bitwise leftshift
# 1011 << 2  →  101100
# Out:
# 2
# 3
# 1
# -4
# 2
# 44

# %%
# assignment
a = 3
a += 4
print(a)
# a +=,-=,/=,*=,//=,**=
# not in py a++,++a,a--,--a
# Out:
# 7

# %%
# membership
# in / not in
print('D' in "Delhi")
print('a' not in 'delhi')
# Out:
# True
# True

# %%
# program -- find the sum of 3 digit number entered by user
n = int(input("enter a 3 digit number "))
sum = 0
while n>0:
    sum += n%10
    n //= 10
print(sum)
# Out:
# enter a 3 digit number  345
# 12

# %% [markdown]
# # If-else statement

# %% [markdown]
# # Modules in Py
# 1. math
# 2. keyword
# 3. datetime
# 4. random

# %%
# math
import math

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
#keyword
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
# random
import random
print(random.randint(1,100))
# Out:
# 15

# %%
# datetime
import datetime
print(datetime.datetime.now())
# Out:
# 2025-08-23 17:52:04.913348

# %%
help('modules')
# Out:
# Please wait a moment while I gather a list of all available modules...
#
# 3204bda914b7f2c6f497__mypyc collection          mdurl               sniffio
# IPython             collections         menuinst            snowballstemmer
# OpenSSL             colorama            mimetypes           socket
# PIL                 colorcet            missingno           socketserver
# PyQt5               colorsys            mistune             socks
# __future__          comm                mkl                 sockshandler
# __hello__           commctrl            mkl_fft             sortedcontainers
# __phello__          compileall          mkl_random          soupsieve
# _abc                concurrent          mmap                sphinx
# _aix_support        conda               mmapfile            sphinxify
# _argon2_cffi_bindings conda_build         mmsystem            sphinxthread
# _ast                conda_content_trust modulefinder        spyder
# ...

# %% [markdown]
# # Loops In  Py
# 1. for
# 2. while
#    * we can use else with while

# %%
i = 1
while(i<6):
    print(i)
    i+=1
else:
    print("limit crossed")
# Out:
# 1
# 2
# 3
# 4
# 5
# limit crossed

# %% [markdown]
# # Loop control statement
# * Break
# * Continue
# * Pass

# %% [markdown]
# Question---the current population of a town is 10000 . the population of the town is increasing at the rate of 10% per year. you have to write a program to find out the population at the end of each of the last 10 years.

# %% [markdown]
# x + 0.1x = 1000

# %%
curr_popu = 1000
for i in range(10,0,-1):
    curr_popu = curr_popu/1.1
    print(curr_popu)

# %% [markdown]
# Sequence Sum
# * 1/1! + 2/2! + 3/3!+.....

# %%
n = int(input("enter number of terms"))
sum = 0
fact =1
for i in range(1,n+1):
    fact *= i
    sum += i/fact
print(sum)

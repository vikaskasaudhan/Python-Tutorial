# %% [markdown]
# # Class Relationships
# * Aggregation
# * Inheritance

# %% [markdown]
# ### Aggregation(has a relationship)

# %%
class Customer:

    def __init__(self,name,gender,address):
        self.name = name
        self.gender = gender
        self.address = address

    def print_address(self):
        # print(self.address.city,self.address.pin,self.address.state)
        print(self.address.get_city(),self.address.pin,self.address.state)


    def edit_profile(self,new_name,new_city,new_pin,new_state):
        self.name = new_name
        self.address.edit_address(new_city,new_pin,new_state)


class Address:

    def __init__(self,city,pin,state):
        # self.city = city
        self.__city = city
        self.pin = pin
        self.state = state

    def get_city(self):
        return self.__city

    def edit_address(self,new_city,new_pin,new_state):
        self.__city = new_city
        self.pin = new_pin
        self.state = new_state

add1 = Address('gurgawn',12345,'Haryana')
cust = Customer('vikas','male',add1)

# %%
cust.print_address()
# Out:
# gurgawn 12345 Haryana

# %%
cust.edit_profile('nitish','mumbai',34567,'Maharashtra')

# %%
cust.print_address()
# Out:
# mumbai 34567 Maharashtra

# %% [markdown]
# ## Inheritance
# * What is Inheritance
# * Example
# * What gets inherited

# %%
# inheritance and its benefits

# %%
# Example

class User:

    def __init__(self):
        self.name = 'vikas'

    def login(self):
        print('login')
    def register(self):
        print('register')


# child
class Student(User):

    def __init__(self):
        self.roll = 100

    def enroll(self):
        print('enrolled ino the course')


u = User()
s = Student()

# %%
s.name
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[279], line 1
# ----> 1 s.name
#
# AttributeError: 'Student' object has no attribute 'name'

# %%
s.roll

# %%
s.login()
# Out:
# login

# %%
s.enroll()
# Out:
# enrolled ino the course

# %% [markdown]
# ### What gets Inherited?
# * Constructor
# * Non Private Attributes
# * Non Private Methods

# %%
# Constructor example

class Phone:

    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.price = price
        self.brand = brand 
        self.camera = camera

    def buy(self):
        print("Buying a phone")

class SmartPhone(Phone):

    pass

# %%
s =SmartPhone(20000,'Apple',13)
# Out:
# inside phone constructor

# %%
s.buy()
# Out:
# Buying a phone

# %%
s.brand
# Out:
# 'Apple'

# %%
s.camera
# Out:
# 13

# %%
s.price
# Out:
# 20000

# %%
# child class can not call parent constructor 

class Phone:

    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.price = price
        self.brand = brand 
        self.camera = camera


class SmartPhone(Phone):

    def __init__(self,os,ram):
        self.os = os
        self.ram = ram
        print("inside smartphone constructor")

    def buy(self):
        print("buying a smartphone")

# %%
s = SmartPhone('Android',2)
# Out:
# inside smartphone constructor

# %%
s.buy()
# Out:
# buying a smartphone

# %%
# child can't access private member of the parent class

class Phone:

    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.__price = price
        self.brand = brand 
        self.camera = camera

    # act like a getter 
    def __show(self):
        print(self.__price)

class SmartPhone(Phone):

    def check(self):
        print(self.__price)

# %%
s = SmartPhone(20000,'Apple',13)
# Out:
# inside phone constructor

# %%
s.brand
# Out:
# 'Apple'

# %%
s.check()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[313], line 1
# ----> 1 s.check()
#
# Cell In[292], line 18, in SmartPhone.check(self)
#      17 def check(self):
# ---> 18     print(self.__price)
#
# AttributeError: 'SmartPhone' object has no attribute '_SmartPhone__price'

# %%
s.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[314], line 1
# ----> 1 s.show()
#
# AttributeError: 'SmartPhone' object has no attribute 'show'

# %%
s.camera
# Out:
# 13

# %%
class Parent:

    def __init__(self,num):
        self.__num = num

    def get_num(self):
        return self.__num

class Child(Parent):

    def show(self):
        print("this is in child class")

# %%
son = Child(100)
print(son.get_num())
son.show()
# Out:
# 100
# this is in child class

# %%
print(son.get_num())
# Out:
# 100

# %%
son.show()
# Out:
# this is in child class

# %%
# child class not called the parent constructor
class Parent:

    def __init__(self,num):
        self.__num = num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,val,num):
        self.__val = val

    def get_val(self):
        return self.__val

# %%
son = Child(100,10)
print("Parent : Num:",son.get_num())
print("Child:val:",son.get_val())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[321], line 2
#       1 son = Child(100,10)
# ----> 2 print("Parent : Num:",son.get_num())
#       3 print("Child:val:",son.get_val())
#
# Cell In[320], line 8, in Parent.get_num(self)
#       7 def get_num(self):
# ----> 8     return self.__num
#
# AttributeError: 'Child' object has no attribute '_Parent__num'

# %%
print("Child:val:",son.get_val())

# %%
print("Parent : Num:",son.get_num())

# %%
class A:
    def __init__(self):
        self.var1 = 100

    def display1(self,var1):
        print("class A :",self.var1)

class B(A):

    def display2(self,var1):
        print("class B:",self.var1)

# %%
obj = B()
obj.display1(200)
# Out:
# class A : 100

# %%
obj.display2(200)
# Out:
# class B: 100

# %%
obj.var1
# Out:
# 100

# %%
# method overriding
class Phone:

    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.__price = price
        self.brand = brand 
        self.camera = camera

    def buy(self):
        print("Buying a phone")

class SmartPhone(Phone):

     def buy(self):
        print("Buying a smartphone")

# %%
s = SmartPhone(20000,'Apple',13)
s.buy()
# Out:
# inside phone constructor
# Buying a smartphone

# %% [markdown]
# ## Super Kayword

# %%
class Phone:

    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.__price = price
        self.brand = brand 
        self.camera = camera

    def buy(self):
        print("Buying a phone")

class SmartPhone(Phone):

     def buy(self):
        print("Buying a smartphone")
         # syntax to call parent's method
        super().buy()

# %%
s = SmartPhone(20000,'Apple',13)
s.buy()
# Out:
# inside phone constructor
# Buying a smartphone
# Buying a phone

# %%
# super --> constructor

class Phone:

    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.__price = price
        self.brand = brand 
        self.camera = camera


class SmartPhone(Phone):

    def __init__(self,price,brand,camera,os,ram):
        print("inside smartphone constructor")
        super().__init__(price,brand,camera)
        self.os = os
        self.ram = ram
        print("inside smartphone constructor")

# %%
s = SmartPhone(20000,'Apple',13,'Android',3)
# Out:
# inside smartphone constructor
# inside phone constructor
# inside smartphone constructor

# %%
# using super outside the class
class Phone:

    def __init__(self,price,brand,camera):
        print("inside phone constructor")
        self.__price = price
        self.brand = brand 
        self.camera = camera

    def buy(self):
        print("Buying a phone")

class SmartPhone(Phone):

     def buy(self):
        print("Buying a smartphone")

# %%
s = SmartPhone(20000,'Apple',13)
s.super().buy()
# Out:
# inside phone constructor
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[357], line 2
#       1 s = SmartPhone(20000,'Apple',13)
# ----> 2 s.super().buy()
#
# AttributeError: 'SmartPhone' object has no attribute 'super'

# %%
class Parent:

    def __init__(self,num):
        self.__num = num

    def get_num(self):
        return self.__num

class Child(Parent):

    def __init__(self,num,val):
        super().__init__(num)
        self.__val = val

    def get_val(self):
        return self.__val

# %%
son = Child(100,200)
print("Parent : Num:",son.get_num())
print("Child:val:",son.get_val())

# %%
class Parent:

    def __init__(self):
        self.num = 100

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.val = 200

    def show(self):
        print(self.num)
        print(self.val)
        print(self.num)

# %%
son = Child()
son.show()

# %%
class Parent:

    def __init__(self):
        self.__num = 100

    def show(self):
        print("Parent:",self.__num)

class Child(Parent):

    def __init__(self):
        super().__init__()
        self.__val = 10

    def show(self):
        print("Parent:",self.__val)

# %%
obj = Child()
obj.show()

# %% [markdown]
# ## Types of Inheritance
# * Single
# * Multilevel
# * Multiple (diamond problem)
# * Hybrid
# * Hierarchical

# %% [markdown]
# ## Polymorphism
# * Method Overriding
# * Method Overloading
# * Operator Overloading
#
# reason --> code looks clean and readibility increase

# %% [markdown]
# Method Overloading not work in python

# %% [markdown]
# ## Abstraction

# %%
from abc import ABC, abstractmethod
class BankApp(ABC):

    def database(self):
        print("connected to database")


    @abstractmethod
    def security(self):
        pass

    @abstractmethod
    def display(self):
        pass

# %%
class MobileApp(BankApp):
    def mobile_login(self):
        print("login into mobile")

    def security(self):
        print("mobile security")

    def display(self):
        print("mobile display")

# %%
mob = MobileApp()

# %%
mob.database()
# Out:
# connected to database

# %%
mob.mobile_login()
# Out:
# login into mobile

# %%
mob.security()
# Out:
# mobile security
